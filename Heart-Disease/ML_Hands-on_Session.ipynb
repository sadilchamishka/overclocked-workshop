# %%
import pandas as pd

# %% [markdown]
# <h2>Understanding the Dataset

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#      age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  slope  ca  \
# 0     63    male   3       145   233  1.0        0      150    0.0    0.0   0
# 1     37    male   2       130   250  0.0        1      187    0.0    0.0   0
# 2     41  female   1       130   204  0.0        0      172    0.0    2.0   0
# 3     56    male   1       120   236  0.0        1      178    0.0    2.0   0
# 4     57  female   0       120   354  0.0        1      163    1.0    2.0   0
# 5     57    male   0       140   192  0.0        1      148    0.0    1.0   0
# 6     56  female   1       140   294  0.0        0      153    0.0    1.0   0
# 7     44    male   1       120   263  0.0        1      173    0.0    2.0   0
# 8     52    male   2       172   199  1.0        1      162    0.0    2.0   0
# 9     57    male   2       150   168  0.0        1      174    0.0    2.0   0
# 10    54    male   0       140   239  0.0        1      160    0.0    2.0   0
# 11    48  female   2       130   275  0.0        1      139    0.0    2.0   0
# 12    49    male   1       130   266  0.0        1      171    0.0    2.0   0
# 13    64    male   3       110   211  0.0        0      144    1.0    1.0   0
# 14    58  female   3       150   283  1.0        0      162    0.0    2.0   0
# 15    50  female   2       120   219  0.0        1      158    0.0    1.0   0
# 16    58  female   2       120   340  0.0        1      172    0.0    2.0   0
# 17    66  female   3       150   226  0.0        1      114    0.0    0.0   0
# 18    43    male   0       150   247  0.0        1      171    0.0    2.0   0
# 19    69  female   3       140   239  0.0        1      151    0.0    2.0   2
# 20    59    male   0       135   234  0.0        1      161    0.0    1.0   0
# 21    44    male   2       130   233  0.0        1      179    1.0    2.0   0
# 22    42    male   0       140   226  0.0        1      178    0.0    2.0   0
# 23    61    male   2       150   243  1.0        1      137    1.0    1.0   0
# 24    40    male   3       140   199  0.0        1      178    1.0    2.0   0
# 25    71  female   1       160   302  0.0        1      162    0.0    2.0   2
# 26    59    male   2       150   212  1.0        1      157    0.0    2.0   0
# 27    51    male   2       110   175  0.0        1      123    0.0    2.0   0
# 28    65  female   2       140   417  1.0        0      157    0.0    2.0   1
# 29    53    male   2       130   197  1.0        0      152    0.0    0.0   0
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...    ...  ..
# 273   58    male   0       100   234  0.0        1      156    0.0    2.0   1
# 274   47    male   0       110   275  0.0        0      118    1.0    1.0   1
# 275   52    male   0       125   212  0.0        1      168    0.0    2.0   2
# 276   58    male   0       146   218  0.0        1      105    0.0    1.0   1
# 277   57    male   1       124   261  0.0        1      141    0.0    2.0   0
# 278   58  female   1       136   319  1.0        0      152    0.0    2.0   2
# 279   61    male   0       138   166  0.0        0      125    1.0    1.0   1
# 280   42    male   0       136   315  0.0        1      125    1.0    1.0   0
# 281   52    male   0       128   204  1.0        1      156    1.0    1.0   0
# 282   59    male   2       126   218  1.0        1      134    0.0    1.0   1
# 283   40    male   0       152   223  0.0        1      181    0.0    2.0   0
# 284   61    male   0       140   207  0.0        0      138    1.0    2.0   1
# 285   46    male   0       140   311  0.0        1      120    1.0    1.0   2
# 286   59    male   3       134   204  0.0        1      162    0.0    2.0   2
# 287   57    male   1       154   232  0.0        0      164    0.0    2.0   1
# 288   57    male   0       110   335  0.0        1      143    1.0    1.0   1
# 289   55  female   0       128   205  0.0        2      130    1.0    1.0   1
# 290   61    male   0       148   203  0.0        1      161    0.0    2.0   1
# 291   58    male   0       114   318  0.0        2      140    0.0    0.0   3
# 292   58  female   0       170   225  1.0        0      146    1.0    1.0   2
# 293   67    male   2       152   212  0.0        0      150    0.0    1.0   0
# 294   44    male   0       120   169  0.0        1      144    1.0    0.0   0
# 295   63    male   0       140   187  0.0        0      144    1.0    2.0   2
# 296   63  female   0       124   197  0.0        1      136    1.0    1.0   0
# 297   59    male   0       164   176  1.0        0       90    0.0    1.0   2
# 298   57  female   0       140   241  0.0        1      123    1.0    1.0   0
# 299   45    male   3       110   264  0.0        1      132    0.0    1.0   0
# 300   68    male   0       144   193  1.0        1      141    0.0    1.0   2
# 301   57    male   0       130   131  0.0        1      115    1.0    1.0   1
# 302   57  female   1       130   236  0.0        0      174    0.0    1.0   1
#
#      thal  target
# 0     1.0       1
# 1     2.0       1
# 2     2.0       1
# 3     2.0       1
# 4     2.0       1
# 5     1.0       1
# 6     2.0       1
# 7     3.0       1
# 8     3.0       1
# 9     2.0       1
# 10    2.0       1
# 11    2.0       1
# 12    2.0       1
# 13    2.0       1
# 14    2.0       1
# 15    2.0       1
# 16    2.0       1
# 17    2.0       1
# 18    2.0       1
# 19    2.0       1
# 20    3.0       1
# 21    2.0       1
# 22    2.0       1
# 23    2.0       1
# 24    3.0       1
# 25    2.0       1
# 26    2.0       1
# 27    2.0       1
# 28    2.0       1
# 29    2.0       1
# ..    ...     ...
# 273   3.0       0
# 274   2.0       0
# 275   3.0       0
# 276   3.0       0
# 277   3.0       0
# 278   2.0       0
# 279   2.0       0
# 280   1.0       0
# 281   0.0       0
# 282   1.0       0
# 283   3.0       0
# 284   3.0       0
# 285   3.0       0
# 286   2.0       0
# 287   2.0       0
# 288   3.0       0
# 289   3.0       0
# 290   3.0       0
# 291   1.0       0
# 292   1.0       0
# 293   3.0       0
# 294   1.0       0
# 295   3.0       0
# 296   2.0       0
# 297   1.0       0
# 298   3.0       0
# 299   3.0       0
# 300   3.0       0
# 301   3.0       0
# 302   2.0       0
#
# [303 rows x 13 columns]

# %% [markdown]
# The dataset contains the following features:
# 1. age: (in years)
# 2. sex: (male, female)
# 3. cp: chest pain type
# 4. trestbps: resting blood pressure (in mm Hg on admission to the hospital)
# 5. chol: serum cholestoral in mg/dl
# 6. fbs: (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
# 7. restecg: resting electrocardiographic results
# 8. thalach: maximum heart rate achieved
# 9. exang: exercise induced angina (1 = yes; 0 = no)
# 10. slope: the slope of the peak exercise ST segment
# 11. ca: number of major vessels (0-3) colored by flourosopy
# 12. thal: 3 = normal; 6 = fixed defect; 7 = reversable defect
# 13. target: 1 or 0

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# cp            int64
# trestbps      int64
# chol          int64
# fbs         float64
# restecg       int64
# thalach       int64
# exang       float64
# slope       float64
# ca            int64
# thal        float64
# target        int64
# dtype: object

# %%
df.shape
# Out:
# (303, 13)

# %%
df.describe()
# Out:
#               age          cp    trestbps        chol         fbs     restecg  \
# count  303.000000  303.000000  303.000000  303.000000  302.000000  303.000000
# mean    54.366337    0.966997  131.623762  246.264026    0.149007    0.528053
# std      9.082101    1.032052   17.538143   51.830751    0.356686    0.525860
# min     29.000000    0.000000   94.000000  126.000000    0.000000    0.000000
# 25%     47.500000    0.000000  120.000000  211.000000    0.000000    0.000000
# 50%     55.000000    1.000000  130.000000  240.000000    0.000000    1.000000
# 75%     61.000000    2.000000  140.000000  274.500000    0.000000    1.000000
# max     77.000000    3.000000  200.000000  564.000000    1.000000    2.000000
#
#           thalach       exang       slope          ca        thal      target
# count  303.000000  301.000000  301.000000  303.000000  302.000000  303.000000
# mean   149.646865    0.328904    1.395349    0.729373    2.314570    0.544554
# std     22.905161    0.470597    0.616316    1.022606    0.613026    0.498835
# min     71.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%    133.500000    0.000000    1.000000    0.000000    2.000000    0.000000
# 50%    153.000000    0.000000    1.000000    0.000000    2.000000    1.000000
# 75%    166.000000    1.000000    2.000000    1.000000    3.000000    1.000000
# max    202.000000    1.000000    2.000000    4.000000    3.000000    1.000000

# %% [markdown]
# **The features described in the above data set are**
#
# 1. Count = Number of non-empty rows in a feature
# 2. Mean  = Mean value of a feature
# 3. Std   = Standard Deviation Value of a feature
# 4. Min   = Minimum value of a feature
# 5. 25%, 50%, and 75% = Percentile/quartile of each feature
# 6. Max   = Maximum value of a feature

# %% [markdown]
# <h2>Handling Missing Values

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         1
# restecg     0
# thalach     0
# exang       2
# slope       2
# ca          0
# thal        1
# target      0
# dtype: int64

# %% [markdown]
# <h3>Fill NULL Values

# %%
df=df.fillna(method='ffill')
df
# Out:
#      age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  slope  ca  \
# 0     63    male   3       145   233  1.0        0      150    0.0    0.0   0
# 1     37    male   2       130   250  0.0        1      187    0.0    0.0   0
# 2     41  female   1       130   204  0.0        0      172    0.0    2.0   0
# 3     56    male   1       120   236  0.0        1      178    0.0    2.0   0
# 4     57  female   0       120   354  0.0        1      163    1.0    2.0   0
# 5     57    male   0       140   192  0.0        1      148    0.0    1.0   0
# 6     56  female   1       140   294  0.0        0      153    0.0    1.0   0
# 7     44    male   1       120   263  0.0        1      173    0.0    2.0   0
# 8     52    male   2       172   199  1.0        1      162    0.0    2.0   0
# 9     57    male   2       150   168  0.0        1      174    0.0    2.0   0
# 10    54    male   0       140   239  0.0        1      160    0.0    2.0   0
# 11    48  female   2       130   275  0.0        1      139    0.0    2.0   0
# 12    49    male   1       130   266  0.0        1      171    0.0    2.0   0
# 13    64    male   3       110   211  0.0        0      144    1.0    1.0   0
# 14    58  female   3       150   283  1.0        0      162    0.0    2.0   0
# 15    50  female   2       120   219  0.0        1      158    0.0    1.0   0
# 16    58  female   2       120   340  0.0        1      172    0.0    2.0   0
# 17    66  female   3       150   226  0.0        1      114    0.0    0.0   0
# 18    43    male   0       150   247  0.0        1      171    0.0    2.0   0
# 19    69  female   3       140   239  0.0        1      151    0.0    2.0   2
# 20    59    male   0       135   234  0.0        1      161    0.0    1.0   0
# 21    44    male   2       130   233  0.0        1      179    1.0    2.0   0
# 22    42    male   0       140   226  0.0        1      178    0.0    2.0   0
# 23    61    male   2       150   243  1.0        1      137    1.0    1.0   0
# 24    40    male   3       140   199  0.0        1      178    1.0    2.0   0
# 25    71  female   1       160   302  0.0        1      162    0.0    2.0   2
# 26    59    male   2       150   212  1.0        1      157    0.0    2.0   0
# 27    51    male   2       110   175  0.0        1      123    0.0    2.0   0
# 28    65  female   2       140   417  1.0        0      157    0.0    2.0   1
# 29    53    male   2       130   197  1.0        0      152    0.0    0.0   0
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...    ...  ..
# 273   58    male   0       100   234  0.0        1      156    0.0    2.0   1
# 274   47    male   0       110   275  0.0        0      118    1.0    1.0   1
# 275   52    male   0       125   212  0.0        1      168    0.0    2.0   2
# 276   58    male   0       146   218  0.0        1      105    0.0    1.0   1
# 277   57    male   1       124   261  0.0        1      141    0.0    2.0   0
# 278   58  female   1       136   319  1.0        0      152    0.0    2.0   2
# 279   61    male   0       138   166  0.0        0      125    1.0    1.0   1
# 280   42    male   0       136   315  0.0        1      125    1.0    1.0   0
# 281   52    male   0       128   204  1.0        1      156    1.0    1.0   0
# 282   59    male   2       126   218  1.0        1      134    0.0    1.0   1
# 283   40    male   0       152   223  0.0        1      181    0.0    2.0   0
# 284   61    male   0       140   207  0.0        0      138    1.0    2.0   1
# 285   46    male   0       140   311  0.0        1      120    1.0    1.0   2
# 286   59    male   3       134   204  0.0        1      162    0.0    2.0   2
# 287   57    male   1       154   232  0.0        0      164    0.0    2.0   1
# 288   57    male   0       110   335  0.0        1      143    1.0    1.0   1
# 289   55  female   0       128   205  0.0        2      130    1.0    1.0   1
# 290   61    male   0       148   203  0.0        1      161    0.0    2.0   1
# 291   58    male   0       114   318  0.0        2      140    0.0    0.0   3
# 292   58  female   0       170   225  1.0        0      146    1.0    1.0   2
# 293   67    male   2       152   212  0.0        0      150    0.0    1.0   0
# 294   44    male   0       120   169  0.0        1      144    1.0    0.0   0
# 295   63    male   0       140   187  0.0        0      144    1.0    2.0   2
# 296   63  female   0       124   197  0.0        1      136    1.0    1.0   0
# 297   59    male   0       164   176  1.0        0       90    0.0    1.0   2
# 298   57  female   0       140   241  0.0        1      123    1.0    1.0   0
# 299   45    male   3       110   264  0.0        1      132    0.0    1.0   0
# 300   68    male   0       144   193  1.0        1      141    0.0    1.0   2
# 301   57    male   0       130   131  0.0        1      115    1.0    1.0   1
# 302   57  female   1       130   236  0.0        0      174    0.0    1.0   1
#
#      thal  target
# 0     1.0       1
# 1     2.0       1
# 2     2.0       1
# 3     2.0       1
# 4     2.0       1
# 5     1.0       1
# 6     2.0       1
# 7     3.0       1
# 8     3.0       1
# 9     2.0       1
# 10    2.0       1
# 11    2.0       1
# 12    2.0       1
# 13    2.0       1
# 14    2.0       1
# 15    2.0       1
# 16    2.0       1
# 17    2.0       1
# 18    2.0       1
# 19    2.0       1
# 20    3.0       1
# 21    2.0       1
# 22    2.0       1
# 23    2.0       1
# 24    3.0       1
# 25    2.0       1
# 26    2.0       1
# 27    2.0       1
# 28    2.0       1
# 29    2.0       1
# ..    ...     ...
# 273   3.0       0
# 274   2.0       0
# 275   3.0       0
# 276   3.0       0
# 277   3.0       0
# 278   2.0       0
# 279   2.0       0
# 280   1.0       0
# 281   0.0       0
# 282   1.0       0
# 283   3.0       0
# 284   3.0       0
# 285   3.0       0
# 286   2.0       0
# 287   2.0       0
# 288   3.0       0
# 289   3.0       0
# 290   3.0       0
# 291   1.0       0
# 292   1.0       0
# 293   3.0       0
# 294   1.0       0
# 295   3.0       0
# 296   2.0       0
# 297   1.0       0
# 298   3.0       0
# 299   3.0       0
# 300   3.0       0
# 301   3.0       0
# 302   2.0       0
#
# [303 rows x 13 columns]

# %% [markdown]
# <h3>Some Other Methods of Filling Null Values</h3>
#
# **df.fillna(0)** - fill with "0" <br>
# **df.fillna(method='bfill')** - fill with before value <br>
# **df.fillna({'age': 10, 'sex': 1, 'cp': 1, 'trestbps': 130})** - fill with given values
#
# <h3>Drop Null Value Rows</h3>
#
# **df.dropna()**

# %% [markdown]
# <h1>Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h2>Plot Features

# %%
sns.distplot(df['thalach'], kde = False, color='blue')

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(30,20))
plt.rcParams.update({'font.size': 30})
sns.countplot(x='age',data = df, hue = 'target',palette='GnBu')
plt.show()

# %% [markdown]
# <h2>Scatter Plots

# %%
plt.figure(figsize=(8,6))
plt.rcParams.update({'font.size': 20})
sns.scatterplot(x='trestbps',y='thalach',data=df, hue='target')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='target',y='thalach',data=df, hue='sex')
plt.show()

# %% [markdown]
# <h2>Swarm Plot

# %%
plt.figure(figsize=(8,6))
sns.swarmplot(x='target',y='thalach',data=df, hue='sex')
plt.show()

# %% [markdown]
# <h2>Box Plot

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='target',y='thalach',data=df, hue='sex')
plt.show()

# %% [markdown]
# <h1>Data Preprocessing

# %% [markdown]
# <h2>Outlier Removal

# %% [markdown]
# <h3>Using Z-Score Approach

# %%
import numpy as np
from scipy import stats

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='trestbps',y='thalach',data=df, hue='target')
plt.show()

# %%
df2 = df[(np.abs(stats.zscore(df['thalach'])) < 3)]
df2 = df2[(np.abs(stats.zscore(df2['trestbps'])) < 3)]

# %%
df.shape[0]
# Out:
# 303

# %%
df2.shape[0]
# Out:
# 300

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='trestbps',y='thalach',data=df2, hue='target')
plt.show()

# %% [markdown]
# <h3>Using Quantile Approach

# %%
q = df['thalach'].quantile(0.9)
df3 = df[df['thalach'] < q]

q = df3['trestbps'].quantile(0.98)
df3 = df3[df3['trestbps'] < q]

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='trestbps',y='thalach',data=df3, hue='target')
plt.show()

# %%
df3.shape[0]
# Out:
# 266

# %%
df = df3

# %%
df
# Out:
#      age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  slope  ca  \
# 0     63    male   3       145   233  1.0        0      150    0.0    0.0   0
# 2     41  female   1       130   204  0.0        0      172    0.0    2.0   0
# 4     57  female   0       120   354  0.0        1      163    1.0    2.0   0
# 5     57    male   0       140   192  0.0        1      148    0.0    1.0   0
# 6     56  female   1       140   294  0.0        0      153    0.0    1.0   0
# 7     44    male   1       120   263  0.0        1      173    0.0    2.0   0
# 8     52    male   2       172   199  1.0        1      162    0.0    2.0   0
# 9     57    male   2       150   168  0.0        1      174    0.0    2.0   0
# 10    54    male   0       140   239  0.0        1      160    0.0    2.0   0
# 11    48  female   2       130   275  0.0        1      139    0.0    2.0   0
# 300   68    male   0       144   193  1.0        1      141    0.0    1.0   2
# 301   57    male   0       130   131  0.0        1      115    1.0    1.0   1
# 302   57  female   1       130   236  0.0        0      174    0.0    1.0   1
#
#      thal  target
# 0     1.0       1
# 2     2.0       1
# 4     2.0       1
# 5     1.0       1
# 6     2.0       1
# 7     3.0       1
# 8     3.0       1
# 9     2.0       1
# 10    2.0       1
# 11    2.0       1
# 12    2.0       1
# 13    2.0       1
# 14    2.0       1
# 15    2.0       1
# 16    2.0       1
# 17    2.0       1
# 18    2.0       1
# 19    2.0       1
# 20    3.0       1
# 23    2.0       1
# 25    2.0       1
# 26    2.0       1
# 27    2.0       1
# 28    2.0       1
# 29    2.0       1
# 30    2.0       1
# 31    3.0       1
# 33    2.0       1
# 34    2.0       1
# 35    2.0       1
# ..    ...     ...
# 272   2.0       0
# 273   3.0       0
# 274   2.0       0
# 275   3.0       0
# 276   3.0       0
# 277   3.0       0
# 278   2.0       0
# 279   2.0       0
# 280   1.0       0
# 281   0.0       0
# 282   1.0       0
# 284   3.0       0
# 285   3.0       0
# 286   2.0       0
# 287   2.0       0
# 288   3.0       0
# 289   3.0       0
# 290   3.0       0
# 291   1.0       0
# 292   1.0       0
# 293   3.0       0
# 294   1.0       0
# 295   3.0       0
# 296   2.0       0
# 297   1.0       0
# 298   3.0       0
# 299   3.0       0
# 300   3.0       0
# 301   3.0       0
# 302   2.0       0
#
# [266 rows x 13 columns]

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# <h2>Encoding Categorical Variables

# %%
from sklearn import preprocessing

# %%
df.head()
# Out:
#    age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  slope  ca  \
# 0   63    male   3       145   233  1.0        0      150    0.0    0.0   0
# 1   41  female   1       130   204  0.0        0      172    0.0    2.0   0
# 2   57  female   0       120   354  0.0        1      163    1.0    2.0   0
# 3   57    male   0       140   192  0.0        1      148    0.0    1.0   0
# 4   56  female   1       140   294  0.0        0      153    0.0    1.0   0
#
#    thal  target
# 0   1.0       1
# 1   2.0       1
# 2   2.0       1
# 3   1.0       1
# 4   2.0       1

# %%
label_encoder = preprocessing.LabelEncoder()
df['sex'] = label_encoder.fit_transform(df['sex'])
df.head(3)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  slope  ca  \
# 0   63    1   3       145   233  1.0        0      150    0.0    0.0   0
# 1   41    0   1       130   204  0.0        0      172    0.0    2.0   0
# 2   57    0   0       120   354  0.0        1      163    1.0    2.0   0
#
#    thal  target
# 0   1.0       1
# 1   2.0       1
# 2   2.0       1

# %% [markdown]
# <h2>Data Normalization

# %%
x = df[['age','trestbps','chol', 'thalach']].values
min_max_scaler = preprocessing.MinMaxScaler()
df_scaled = min_max_scaler.fit_transform(x)
df_scaled
# Out:
# /home/deshanig/.local/lib/python2.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([[0.6744186 , 0.6375    , 0.24429224, 0.75961538],
#        [0.1627907 , 0.45      , 0.17808219, 0.97115385],
#        [0.53488372, 0.325     , 0.52054795, 0.88461538],
#        ...,
#        [0.79069767, 0.625     , 0.15296804, 0.67307692],
#        [0.53488372, 0.45      , 0.01141553, 0.42307692],
#        [0.53488372, 0.45      , 0.25114155, 0.99038462]])

# %%
pd.DataFrame(df_scaled)
# Out:
#             0       1         2         3
# 0    0.674419  0.6375  0.244292  0.759615
# 1    0.162791  0.4500  0.178082  0.971154
# 255    1.0   2   1.0       0
# 256    1.0   0   3.0       0
# 257    0.0   0   1.0       0
# 258    2.0   2   3.0       0
# 259    1.0   0   2.0       0
# 260    1.0   2   1.0       0
# 261    1.0   0   3.0       0
# 262    1.0   0   3.0       0
# 263    1.0   2   3.0       0
# 264    1.0   1   3.0       0
# 265    1.0   1   2.0       0
#
# [266 rows x 13 columns]

# %% [markdown]
# <h1>Feature Engineering

# %% [markdown]
# <h3>Correlation Analysis

# %%
plt.figure(figsize=(18,18))
plt.rcParams["axes.labelsize"] = 20
sns.set(font_scale=1.4)
sns.heatmap(df.corr(), annot = True ,linewidths=.1)
plt.show()

# %%
def find_correlation(data, threshold=0.9):
    corr_mat = data.corr()
    corr_mat.loc[:, :] = np.tril(corr_mat, k=-1)
    already_in = set()
    result = []
    for col in corr_mat:
        perfect_corr = corr_mat[col][abs(corr_mat[col])> threshold].index.tolist()
        if perfect_corr and col not in already_in:
            already_in.update(set(perfect_corr))
            perfect_corr.append(col)
            result.append(perfect_corr)
    select_nested = [f[1:] for f in result]
    select_flat = [i for j in select_nested for i in j]
    return select_flat

# %%
columns_to_drop = find_correlation(df.drop(columns=['target']) , 0.9)
df4 = df.drop(columns=columns_to_drop)

# %%
columns_to_drop
# Out:
# []

# %%
df4
# Out:
#           age  sex  cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0    0.674419    1   3    0.6375  0.244292  1.0        0  0.759615    0.0
# 1    0.162791    0   1    0.4500  0.178082  0.0        0  0.971154    0.0
# 2    0.534884    0   0    0.3250  0.520548  0.0        1  0.884615    1.0
# 3    0.534884    1   0    0.5750  0.150685  0.0        1  0.740385    0.0
# 4    0.511628    0   1    0.5750  0.383562  0.0        0  0.788462    0.0
# 5    0.232558    1   1    0.3250  0.312785  0.0        1  0.980769    0.0
# 6    0.418605    1   2    0.9750  0.166667  1.0        1  0.875000    0.0
# 7    0.534884    1   2    0.7000  0.095890  0.0        1  0.990385    0.0
# 8    0.465116    1   0    0.5750  0.257991  0.0        1  0.855769    0.0
# 9    0.325581    0   2    0.4500  0.340183  0.0        1  0.653846    0.0
# 10   0.348837    1   1    0.4500  0.319635  0.0        1  0.961538    0.0
# 11   0.697674    1   3    0.2000  0.194064  0.0        0  0.701923    1.0
# 12   0.558140    0   3    0.7000  0.358447  1.0        0  0.875000    0.0
# 13   0.372093    0   2    0.3250  0.212329  0.0        1  0.836538    0.0
# 14   0.558140    0   2    0.3250  0.488584  0.0        1  0.971154    0.0
# 15   0.744186    0   3    0.7000  0.228311  0.0        1  0.413462    0.0
# 16   0.209302    1   0    0.7000  0.276256  0.0        1  0.961538    0.0
# 17   0.813953    0   3    0.5750  0.257991  0.0        1  0.769231    0.0
# 18   0.581395    1   0    0.5125  0.246575  0.0        1  0.865385    0.0
# 19   0.627907    1   2    0.7000  0.267123  1.0        1  0.634615    1.0
# 20   0.860465    0   1    0.8250  0.401826  0.0        1  0.875000    0.0
# 21   0.581395    1   2    0.7000  0.196347  1.0        1  0.826923    0.0
# 22   0.395349    1   2    0.2000  0.111872  0.0        1  0.500000    0.0
# 6      2.0   0   3.0       1
# 7      2.0   0   2.0       1
# 8      2.0   0   2.0       1
# 9      2.0   0   2.0       1
# 10     2.0   0   2.0       1
# 11     1.0   0   2.0       1
# 12     2.0   0   2.0       1
# 13     1.0   0   2.0       1
# 14     2.0   0   2.0       1
# 15     0.0   0   2.0       1
# 16     2.0   0   2.0       1
# 17     2.0   2   2.0       1
# 18     1.0   0   3.0       1
# 19     1.0   0   2.0       1
# 20     2.0   2   2.0       1
# 21     2.0   0   2.0       1
# 22     2.0   0   2.0       1
# 23     2.0   1   2.0       1
# 24     0.0   0   2.0       1
# 25     2.0   1   2.0       1
# 26     2.0   0   3.0       1
# 27     0.0   1   2.0       1
# 28     2.0   1   2.0       1
# 29     0.0   0   2.0       1
# ..     ...  ..   ...     ...
# 236    1.0   0   2.0       0
# 237    2.0   1   3.0       0
# 238    1.0   1   2.0       0
# 239    2.0   2   3.0       0
# 240    1.0   1   3.0       0
# 241    2.0   0   3.0       0
# 242    2.0   2   2.0       0
# 243    1.0   1   2.0       0
# 244    1.0   0   1.0       0
# 245    1.0   0   0.0       0
# 246    1.0   1   1.0       0
# 247    2.0   1   3.0       0
# 248    1.0   2   3.0       0
# 249    2.0   2   2.0       0
# 250    2.0   1   2.0       0
# 251    1.0   1   3.0       0
# 252    1.0   1   3.0       0
# 253    2.0   1   3.0       0
# 254    0.0   3   1.0       0
# 255    1.0   2   1.0       0
# 256    1.0   0   3.0       0
# 257    0.0   0   1.0       0
# 258    2.0   2   3.0       0
# 259    1.0   0   2.0       0
# 260    1.0   2   1.0       0
# 261    1.0   0   3.0       0
# 262    1.0   0   3.0       0
# 263    1.0   2   3.0       0
# 264    1.0   1   3.0       0
# 265    1.0   1   2.0       0
#
# [266 rows x 13 columns]

# %%
corr = df.corr()
linear_features=abs(corr).target.drop('target').sort_values(ascending=False)[:5].keys()

# %%
abs(corr).target.drop('target').sort_values(ascending=False)[:5].plot(kind='barh')

# %% [markdown]
# <h3>Using Random Forest Classifier to Identify Important Features

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
y = df.copy(deep=True)['target']
model = rf.fit(df.drop('target', axis=1),y)
# Out:
# /home/deshanig/.local/lib/python2.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
importance = rf.feature_importances_
feat_importances_act = pd.Series(importance, index=df.drop('target', axis=1).columns)
feat_importances = feat_importances_act.nlargest(20)
feat_importances.plot(kind='barh')

# %% [markdown]
# <h3>Convert Categorical Variables into Dummy Variables

# %%
df.dtypes
# Out:
# age         float64
# sex           int64
# cp            int64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg       int64
# thalach     float64
# exang       float64
# slope       float64
# ca            int64
# thal        float64
# target        int64
# dtype: object

# %%
df['sex'] = df['sex'].astype('object')
df['cp'] = df['cp'].astype('object')
df['fbs'] = df['fbs'].astype('object')
df['restecg'] = df['restecg'].astype('object')
df['exang'] = df['exang'].astype('object')
df['slope'] = df['slope'].astype('object')
df['thal'] = df['thal'].astype('object')
df.dtypes
# Out:
# age         float64
# sex          object
# cp           object
# trestbps    float64
# chol        float64
# fbs          object
# restecg      object
# thalach     float64
# exang        object
# slope        object
# ca            int64
# thal         object
# target        int64
# dtype: object

# %%
# 262  0.255814   1  3    0.2000  0.315068   0       1  0.586538     0     1
# 263  0.790698   1  0    0.6250  0.152968   1       1  0.673077     0     1
# 264  0.534884   1  0    0.4500  0.011416   0       1  0.423077     1     1
# 265  0.534884   0  1    0.4500  0.251142   0       0  0.990385     0     1
#
#      ca thal  target
# 0     0    1       1
# 1     0    2       1
# 2     0    2       1
# 3     0    1       1
# 4     0    2       1
# 5     0    3       1
# 6     0    3       1
# 7     0    2       1
# 8     0    2       1
# 9     0    2       1
# 10    0    2       1
# 11    0    2       1
# 12    0    2       1
# 13    0    2       1
# 14    0    2       1
# 15    0    2       1
# 16    0    2       1
# 17    2    2       1
# 18    0    3       1
# 19    0    2       1
# 20    2    2       1
# 21    0    2       1
# 22    0    2       1
# 23    1    2       1
# 24    0    2       1
# 25    1    2       1
# 26    0    3       1
# 27    1    2       1
# 28    1    2       1
# 29    0    2       1
# ..   ..  ...     ...
# 236   0    2       0
# 237   1    3       0
# 238   1    2       0
# 239   2    3       0
# 240   1    3       0
# 241   0    3       0
# 242   2    2       0
# 243   1    2       0
# 244   0    1       0
# 245   0    0       0
# 246   1    1       0
# 247   1    3       0
# 248   2    3       0
# 249   2    2       0
# 250   1    2       0
# 251   1    3       0
# 252   1    3       0
# 253   1    3       0
# 254   3    1       0
# 255   2    1       0
# 256   0    3       0
# 257   0    1       0
# 258   2    3       0
# 259   0    2       0
# 260   2    1       0
# 261   0    3       0
# 262   0    3       0
# 263   2    3       0
# 264   1    3       0
# 265   1    2       0
#
# [266 rows x 13 columns]

# %% [markdown]
# <h1>Applying ML Models

# %% [markdown]
# <h2>Split Train and Test sets

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.drop(['target',],1), df['target'], test_size = .2, random_state=10)

# %%
X_train.head()
# Out:
#           age sex cp  trestbps      chol fbs restecg   thalach exang slope  \
# 212  0.511628   1  0     0.475  0.132420   0       0  0.326923     1     1
# 114  0.395349   0  2     0.325  0.385845   0       0  0.826923     0     2
# 1    0.162791   0  1     0.450  0.178082   0       0  0.971154     0     2
# 235  0.627907   1  3     0.500  0.246575   0       1  0.711538     0     1
# 111  0.651163   1  1     0.425  0.187215   1       0  0.663462     0     2
#
#      ca thal
# 212   1    1
# 114   0    2
# 1     0    2
# 235   2    2
# 111   0    2

# %% [markdown]
# <h2>Random Forest Classifier

# %%
from sklearn.metrics import accuracy_score

model = RandomForestClassifier(max_depth=20)
model.fit(X_train, y_train)
predictions = model.predict(X_test)
# cla_pred.append(accuracy_score(y_test,predictions))
print(accuracy_score(y_test,predictions))
# Out:
# 0.8703703703703703

# %%
importance = model.feature_importances_
feat_importances_act = pd.Series(importance, index=X_train.columns)
feat_importances = feat_importances_act.nlargest(20)
feat_importances.plot(kind='barh')

# %% [markdown]
# <h3> Other Models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
#from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score

classifiers=[['Logistic Regression :',LogisticRegression()],
       ['Decision Tree Classification :',DecisionTreeClassifier()],
       ['Random Forest Classification :',RandomForestClassifier()],
       ['Gradient Boosting Classification :', GradientBoostingClassifier()],
       ['Ada Boosting Classification :',AdaBoostClassifier()],
       ['Extra Tree Classification :', ExtraTreesClassifier()],
       ['K-Neighbors Classification :',KNeighborsClassifier()],
       ['Support Vector Classification :',SVC()],
       ['Gaussian Naive Bayes :',GaussianNB()]]
cla_pred=[]
for name,model in classifiers:
    model=model
    model.fit(X_train,y_train)
    predictions = model.predict(X_test)
    cla_pred.append(accuracy_score(y_test,predictions))
    print(name,accuracy_score(y_test,predictions))
# Out:
# ('Logistic Regression :', 0.8888888888888888)
# ('Decision Tree Classification :', 0.8333333333333334)
# ('Random Forest Classification :', 0.8703703703703703)
# ('Gradient Boosting Classification :', 0.8703703703703703)
# ('Ada Boosting Classification :', 0.8148148148148148)
# ('Extra Tree Classification :', 0.8333333333333334)
# ('K-Neighbors Classification :', 0.9074074074074074)
# ('Support Vector Classification :', 0.9444444444444444)
# ('Gaussian Naive Bayes :', 0.8148148148148148)
# /home/deshanig/.local/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/deshanig/.local/lib/python2.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %% [markdown]
# <h2>Hyper Parameter Tuning

# %% [markdown]
# <h3>Using Grid Search

# %%
from sklearn.model_selection import GridSearchCV

svm = SVC()
kernel=['linear', 'rbf'] 
C=[1,0.25,0.5,0.75]
gamma= [1,2,3,'auto']
decision_function_shape=['ovo','ovr']
shrinking=[True,False]

hyperparameters = dict(kernel=kernel, 
                       C=C,
                       gamma=gamma, 
                       decision_function_shape=decision_function_shape,
                       shrinking=shrinking)

h_SVMmodel = GridSearchCV(svm, hyperparameters)
best_SVMmodel=h_SVMmodel.fit(df.drop('target', 1), df['target'])

print('Best Kernel:', best_SVMmodel.best_estimator_.get_params()['kernel'])
print('Best C:', best_SVMmodel.best_estimator_.get_params()['C'])
print('Best Gamma:', best_SVMmodel.best_estimator_.get_params()['gamma'])
print('Best Decision Function Shape:', best_SVMmodel.best_estimator_.get_params()['decision_function_shape'])
print('Best Shrinking:', best_SVMmodel.best_estimator_.get_params()['shrinking'])
# Out:
# /home/deshanig/.local/lib/python2.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# ('Best Kernel:', 'rbf')
# ('Best C:', 0.5)
# ('Best Gamma:', 'auto')
# ('Best Decision Function Shape:', 'ovo')
# ('Best Shrinking:', True)
# /home/deshanig/.local/lib/python2.7/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
model=svm
model.fit(X_train,y_train)
predictions = model.predict(X_test)
cla_pred.append(accuracy_score(y_test,predictions))
print(name,accuracy_score(y_test,predictions))
# Out:
# ('Gaussian Naive Bayes :', 0.9444444444444444)

# %%
model=SVC(C=0.5,decision_function_shape = 'ovo')
model.fit(X_train,y_train)
predictions = model.predict(X_test)
cla_pred.append(accuracy_score(y_test,predictions))
print(name,accuracy_score(y_test,predictions))
# Out:
# ('Gaussian Naive Bayes :', 0.9629629629629629)

# %% [markdown]
# <h2> Model Evaluation

# %%
from sklearn.metrics import confusion_matrix
cm_lr = confusion_matrix(y_test,predictions)

# %%
plt.figure(figsize=(24,12))

plt.subplot(2,3,1)
plt.title("Logistic Regression Confusion Matrix")
sns.heatmap(cm_lr,annot=True,cmap="Blues",fmt="d",cbar=False)

plt.show()

# %% [markdown]
# ![350px-Precisionrecall.svg.png](attachment:350px-Precisionrecall.svg.png)

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
print(accuracy_score(y_test,predictions))
# Out:
# [[24  1]
#  [ 1 28]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        25
#            1       0.97      0.97      0.97        29
#
#    micro avg       0.96      0.96      0.96        54
#    macro avg       0.96      0.96      0.96        54
# weighted avg       0.96      0.96      0.96        54
#
# 0.9629629629629629
